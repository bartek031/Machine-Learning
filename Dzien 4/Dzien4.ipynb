# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
df=pd.read_csv('data/men_shoes.csv',low_memory=False)
df.shape
# Out:
# (18280, 48)

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
mean_price=np.mean(df['prices_amountmin'])
mean_price
# Out:
# 93.53952188183217

# %%
y_true=df['prices_amountmin']
y_pred=[mean_price]*y_true.shape[0]

mean_absolute_error(y_true,y_pred)
# Out:
# 63.968341227870624

# %%
np.log( df['prices_amountmin']+1).hist(bins=100)

# %%
y_true=df['prices_amountmin']
y_pred=[np.median(y_true)]*y_true.shape[0]

mean_absolute_error(y_true,y_pred)
# Out:
# 58.01120240700219

# %%
y_true=df['prices_amountmin']
price_log_mean=np.expm1(np.mean(np.log1p(y_true)))
y_pred=[price_log_mean]*y_true.shape[0]

mean_absolute_error(y_true,y_pred)
# Out:
# 58.03539547661041

# %%
df['brand_cat']=df['brand'].factorize()[0]

# %%
feats=['brand_cat']
X=df[feats].values
Y=df['prices_amountmin'].values

model=DecisionTreeRegressor(max_depth=5)

scores=cross_val_score(model,X,Y,scoring='neg_mean_absolute_error')
np.mean(scores), np.std(scores)
# Out:
# (-58.38655694633361, 4.223555478221712)

# %%
def run_model(feats):
  X=df[feats].values
  Y=df['prices_amountmin'].values

  model=DecisionTreeRegressor(max_depth=5)

  scores=cross_val_score(model,X,Y,scoring='neg_mean_absolute_error')
  return np.mean(scores), np.std(scores)

# %%
run_model(['brand_cat'])
# Out:
# (-58.38655694633361, 4.223555478221712)

# %%
df['manufacturer_cat']=df['manufacturer'].factorize()[0]

# %%
run_model(['manufacturer_cat'])
# Out:
# (-63.133649278023746, 3.394307434888982)

# %%
run_model(['brand_cat','manufacturer_cat'])
# Out:
# (-58.539304199085976, 4.311223231615432)

# %%
# !git add Dzien4.ipynb

# %%
# !git config --global user.email "bartekduda1998@gmail.com"
# !git config --global user.name "Bartek"

# %%
# !git commit -m "Dzień 4 uczenia maszynowego, pierwszy model"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes not staged for commit:
# 	modified:   Dzien 3/Dzien_3.ipynb
# 	modified:   Dzien 4/Dzien4.ipynb
# 	modified:   Dzien 4/Dzien_4.ipynb
#
# no changes added to commit

# %%
github_token='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'
git_url='https://{}@github.com/bartek031/Machine-Learning.git'.format(github_token)

# %%
# !git clone {git_url}
# Out:
# Cloning into 'Machine-Learning'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 23 (delta 5), reused 14 (delta 3), pack-reused 0
# Unpacking objects: 100% (23/23), done.

# %%
cd "/content/drive/My Drive/Colab Notebooks/Machine-Learning"
# Out:
# /content/drive/My Drive/Colab Notebooks/Machine-Learning

# %%
# !git commit -m 'Dzien 4 wyzwania uczenia maszynowego'
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes not staged for commit:
# 	modified:   Dzien 3/Dzien_3.ipynb
# 	modified:   Dzien 4/Dzien4.ipynb
# 	modified:   Dzien 4/Dzien_4.ipynb
#
# no changes added to commit

# %%
# !git rm -r 'Dzien_4'
# Out:
# rm 'Dzien_4/Dzien4.ipynb'

# %%
# !git commit -m "Usunięcie katalogu "
# Out:
# [main eac1e73] Usunięcie katalogu
#  1 file changed, 1 deletion(-)
#  delete mode 100644 Dzien_4/Dzien4.ipynb

# %%
# !git add
# Out:
# git: 'cd' is not a git command. See 'git --help'.
#
# The most similar command is
# 	add
